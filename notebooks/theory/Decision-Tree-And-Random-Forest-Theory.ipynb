# %% [markdown]
# # Decision Tree and Random Forest
#
# In this notebook, we explore the application of the decision tree and the random forest using Python and Sklearn. If you want to explore the theory on these topics you can read this [blog](https://towardsdatascience.com/enchanted-random-forest-b08d418cb411#.hh7n1co54).
#
# The data set used corresponds to a classification of the kyphosis bases using the features of some patients.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Get the Data

# %%
df = pd.read_csv('../../datasets/kyphosis.csv')

# %%
df.head()
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %% [markdown]
# ## EAD
#
# We'll just check out a simples pairplot for this small dataset.

# %%
sns.set_style('ticks')
sns.pairplot(df, hue='Kyphosis', palette='Set1')

# %% [markdown]
# ## Train Test Split
#
# Let's split up the data into a training set and test set.

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Kyphosis', axis=1)
y = df['Kyphosis']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# ## Decision Trees
#
# We'll start just by training a single decision tree.

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %% [markdown]
# ## Prediction and Evaluation
#
# Let's evaluate our decision tree.

# %%
predictions = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test, predictions))
# Out:
#              precision    recall  f1-score   support
#
#      absent       0.76      0.94      0.84        17
#     present       0.75      0.38      0.50         8
#
# avg / total       0.76      0.76      0.73        25

# %%
print(confusion_matrix(y_test, predictions))
# Out:
# [[16  1]
#  [ 5  3]]

# %% [markdown]
# ## Tree Visualization
#
# Scikit learn actually has some built-in visualization capabilities for decision trees, you won't use this often and it requires you to install the Pydot library.
#
# To use you need install the pydot and graphviz:
# - `pip intall pydot`
# - `conda install -c anaconda graphviz=2.38.0`
#
# Here is an example of what it looks like and the code to execute this:

# %%
from IPython.display import Image  
from sklearn.externals.six import StringIO  
from sklearn.tree import export_graphviz
import pydot 

features = list(df.columns[1:])
features

# %%
dot_data = StringIO()  
export_graphviz(dtree, out_file=dot_data,feature_names=features,filled=True,rounded=True)

graph = pydot.graph_from_dot_data(dot_data.getvalue())  
Image(graph[0].create_png())

# %% [markdown]
# ## Random Forests
#
# Now wen can compare the decision tree model a random forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=100)

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rfc_pred = rfc.predict(X_test)

# %%
print(confusion_matrix(y_test, rfc_pred))
# Out:
# [[17  0]
#  [ 6  2]]

# %%
print(classification_report(y_test, predictions))
# Out:
#              precision    recall  f1-score   support
#
#      absent       0.76      0.94      0.84        17
#     present       0.75      0.38      0.50         8
#
# avg / total       0.76      0.76      0.73        25
